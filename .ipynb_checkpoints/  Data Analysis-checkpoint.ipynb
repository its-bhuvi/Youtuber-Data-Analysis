# %%
# !pip install google-api-python-client

# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
api_key='AIzaSyDN1Q1jeER2Dgjthvsq5RfsT3mdAJ11PnU'
channel_ids=['UCh9nVJoWXmFb7sLApWGcLPQ',#codebasics
           'UCNU_lfiiWBdtULKOw6X0Dig',#Krish Naik
           'UCiT9RITQ9PW6BhXK0y2jaeg',#Ken jee
           'UCnz-ZXXER4jOvuED5trXfEA', # TechTFQ
            'UCzAF54cHk1ZO82af-8E3qOQ'] # CareerFoundry
# setup to request and get the respone on youtube api

# %%
youtube=build('youtube','v3', developerKey=api_key)

# %%
def get_channel_id(youtube,channel_ids):
    Channel_data=[]
    request=youtube.channels().list(
            part='snippet,contentDetails,statistics',
            id=','.join(channel_ids))
    response=request.execute()
    
    for i in range(len(response['items'])):
        data=dict(Channel_Name=response['items'][i]['snippet']['title'],
                  Subscriber=response['items'][i]['statistics']['subscriberCount'],
                  Views=response['items'][i]['statistics']['viewCount'],
                  Total_Videos=response['items'][i]['statistics']['videoCount'],
                  playlist_id=response['items'][i]['contentDetails']['relatedPlaylists']['uploads']
                 )
        Channel_data.append(data)
    
    return Channel_data

# %%
get_channel_id(youtube,channel_ids)
# Out:
# [{'Channel_Name': 'codebasics',
#   'Subscriber': '747000',
#   'Views': '51283349',
#   'Total_Videos': '612',
#   'playlist_id': 'UUh9nVJoWXmFb7sLApWGcLPQ'},
#  {'Channel_Name': 'Krish Naik',
#   'Subscriber': '723000',
#   'Views': '70805560',
#   'Total_Videos': '1633',
#   'playlist_id': 'UUNU_lfiiWBdtULKOw6X0Dig'},
#  {'Channel_Name': 'Ken Jee',
#   'Subscriber': '236000',
#   'Views': '7632106',
#   'Total_Videos': '261',
#   'playlist_id': 'UUiT9RITQ9PW6BhXK0y2jaeg'},
#  {'Channel_Name': 'techTFQ',
#   'Subscriber': '171000',
#   'Views': '8198713',
#   'Total_Videos': '84',
#   'playlist_id': 'UUnz-ZXXER4jOvuED5trXfEA'},
#  {'Channel_Name': 'CareerFoundry',
#   'Subscriber': '164000',
#   'Views': '7923941',
#   'Total_Videos': '269',
#   'playlist_id': 'UUzAF54cHk1ZO82af-8E3qOQ'}]

# %%
Channel_statistics=get_channel_id(youtube,channel_ids)

# %%
yt_data=pd.DataFrame(Channel_statistics)

# %%
yt_data
# Out:
#     Channel_Name Subscriber     Views Total_Videos               playlist_id
# 0        techTFQ     171000   8198713           84  UUnz-ZXXER4jOvuED5trXfEA
# 1     codebasics     747000  51283349          612  UUh9nVJoWXmFb7sLApWGcLPQ
# 2        Ken Jee     236000   7632106          261  UUiT9RITQ9PW6BhXK0y2jaeg
# 3  CareerFoundry     164000   7923941          269  UUzAF54cHk1ZO82af-8E3qOQ
# 4     Krish Naik     723000  70805560         1633  UUNU_lfiiWBdtULKOw6X0Dig

# %%
yt_data.dtypes
# Out:
# Channel_Name    object
# Subscriber      object
# Views           object
# Total_Videos    object
# playlist_id     object
# dtype: object

# %%
yt_data['Subscriber']=pd.to_numeric(yt_data['Subscriber'])
yt_data['Views']=pd.to_numeric(yt_data['Views'])
yt_data['Total_Videos']=pd.to_numeric(yt_data['Total_Videos'])

# %%
yt_data.dtypes
# Out:
# Channel_Name    object
# Subscriber       int64
# Views            int64
# Total_Videos     int64
# playlist_id     object
# dtype: object

# %% [markdown]
# ### High Number of Subscriber Count b/w these Youtube Channels

# %%
sns.set(rc={'figure.figsize':(6,6)})
graph=sns.barplot(x='Channel_Name',y='Subscriber', data=yt_data)
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# ### High Number of Views Count b/w these Youtube Channels

# %%
sns.set(rc={'figure.figsize':(6,6)})
graph=sns.barplot(x='Channel_Name',y='Views', data=yt_data)
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# ### High Number of Total_Videos Count b/w these Youtube Channels

# %%
sns.set(rc={'figure.figsize':(6,6)})
graph=sns.barplot(x='Channel_Name',y='Total_Videos', data=yt_data)
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# ### Function to get Video ids

# %%
yt_data
# Out:
#     Channel_Name  Subscriber     Views  Total_Videos               playlist_id
# 0        techTFQ      171000   8198713            84  UUnz-ZXXER4jOvuED5trXfEA
# 1     codebasics      747000  51283349           612  UUh9nVJoWXmFb7sLApWGcLPQ
# 2        Ken Jee      236000   7632106           261  UUiT9RITQ9PW6BhXK0y2jaeg
# 3  CareerFoundry      164000   7923941           269  UUzAF54cHk1ZO82af-8E3qOQ
# 4     Krish Naik      723000  70805560          1633  UUNU_lfiiWBdtULKOw6X0Dig

# %%
# find particular channel_name  by playlist_id
list_id=yt_data.loc[yt_data['Channel_Name']=='Krish Naik','playlist_id'].iloc[0]

# %%
list_id
# Out:
# 'UUNU_lfiiWBdtULKOw6X0Dig'

# %% [markdown]
# ### Function to get one particuler channel video ids

# %%
# To Find the video details on one paeticuler channel
def get_video_ids(youtube,list_id):
    request=youtube.playlistItems().list(
             part='contentDetails',
             playlistId=list_id,
             maxResults=10) # maxresult =50
    response=request.execute()
    return response

# %%
get_video_ids(youtube,list_id)
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': 'kBOJfWwwSZ7K5GZcniWGc5n0FZw',
#  'nextPageToken': 'EAAaBlBUOkNBbw',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': 'jn5xdRrqJp_qIV-vsaCWQleQfaA',
#    'id': 'VVVOVV9sZmlpV0JkdFVMS093NlgwRGlnLjVlcXY4QUt2QmdN',
#    'contentDetails': {'videoId': '5eqv8AKvBgM',
#     'videoPublishedAt': '2023-02-27T08:16:20Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'fwObtaJFTGTZgEYyzCo7tW9oxOI',
#    'id': 'VVVOVV9sZmlpV0JkdFVMS093NlgwRGlnLnVQWUw3SGpDOEZF',
#    'contentDetails': {'videoId': 'uPYL7HjC8FE',
#     'videoPublishedAt': '2023-02-24T14:49:47Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'evfaxKhSGpAVa1Js8_S6gwy9BF0',
#    'id': 'VVVOVV9sZmlpV0JkdFVMS093NlgwRGlnLlk1MVNQaDNCajdZ',
#    'contentDetails': {'videoId': 'Y51SPh3Bj7Y',
#     'videoPublishedAt': '2023-02-24T07:11:12Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'HzAVtC4NqKcrGQjwffrG2nPtJKs',
#    'id': 'VVVOVV9sZmlpV0JkdFVMS093NlgwRGlnLjZaOFNkTjUyR3VV',
#    'contentDetails': {'videoId': '6Z8SdN52GuU',
#     'videoPublishedAt': '2023-02-23T12:36:55Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'UzMkq4da8R6Pm4u2_8u0gWKD9R8',
#    'id': 'VVVOVV9sZmlpV0JkdFVMS093NlgwRGlnLnNxREJFeWZSUG84',
#    'contentDetails': {'videoId': 'sqDBEyfRPo8',
#     'videoPublishedAt': '2023-02-21T14:40:53Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '7VWccG4XDc_8LEM93WrenDf00q0',
#    'id': 'VVVOVV9sZmlpV0JkdFVMS093NlgwRGlnLnkyakxjWGxnQ1hr',
#    'contentDetails': {'videoId': 'y2jLcXlgCXk',
#     'videoPublishedAt': '2023-02-20T14:24:15Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'XuQ7nh7Kij55ChpHbJM5TnKsRUk',
#    'id': 'VVVOVV9sZmlpV0JkdFVMS093NlgwRGlnLlR5ZjFYcmJETnJz',
#    'contentDetails': {'videoId': 'Tyf1XrbDNrs',
#     'videoPublishedAt': '2023-02-16T06:22:29Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'Tn-gsVxtsuBwXBL0ydb6759l7x8',
#    'id': 'VVVOVV9sZmlpV0JkdFVMS093NlgwRGlnLjBtMnI5ZWxSZUJZ',
#    'contentDetails': {'videoId': '0m2r9elReBY',
#     'videoPublishedAt': '2023-02-15T12:05:24Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'HV332RxQo7fG5kZjmyYZrkJHJHg',
#    'id': 'VVVOVV9sZmlpV0JkdFVMS093NlgwRGlnLmJPNU56UFdha1Bz',
#    'contentDetails': {'videoId': 'bO5NzPWakPs',
#     'videoPublishedAt': '2023-02-14T13:29:58Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'tQiBag29s7sW_L-DUABaJxUrDL0',
#    'id': 'VVVOVV9sZmlpV0JkdFVMS093NlgwRGlnLjB2bmF3OHNvaU80',
#    'contentDetails': {'videoId': '0vnaw8soiO4',
#     'videoPublishedAt': '2023-02-13T11:47:54Z'}}],
#  'pageInfo': {'totalResults': 1572, 'resultsPerPage': 10}}

# %%
# To Find the all  video ids on one paeticuler channel
def get_video_ids(youtube,list_id):
    request=youtube.playlistItems().list(
             part='contentDetails',
             playlistId=list_id,
             maxResults=50)
    response=request.execute()
    video_id=[]
    for i in range(len(response['items'])):
        result=response['items'][i]['contentDetails']['videoId']
        video_id.append(result)
        
    next_page_token=response.get('nextPageToken') 
    more_page= True
    
    while more_page:
        if next_page_token is None:
            more_page=False
        else:
            request=youtube.playlistItems().list(
                     part='contentDetails',
                     playlistId=list_id,
                     maxResults=50,
                     pageToken=next_page_token)
            response=request.execute()
            
            for i in range(len(response['items'])):
                    result=response['items'][i]['contentDetails']['videoId']
                    video_id.append(result)
            next_page_token=response.get('nextPageToken')        

    return video_id

# %%
Video_ids=get_video_ids(youtube,list_id)

# %%
len(Video_ids)
# Out:
# 1572

# %% [markdown]
# ### Function to get each  video ids

# %%
def get_video_Details(youtube,Video_ids):
    request=youtube.videos().list(
                part='snippet,statistics',
                id=','.join(Video_ids[:50]))
    response=request.execute()
    
    return response

# %%
 get_video_Details(youtube,Video_ids)
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag

#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6Z8SdN52GuU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6Z8SdN52GuU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6Z8SdN52GuU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/6Z8SdN52GuU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/6Z8SdN52GuU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Krish Naik',
#     'tags': ['yt:cc=on',
#      'differen types of disstirbution',
#      'pdf vs pmf vs cdf',
#      'noormal distribution',
#      'log normal distirbution',
#      'pareto distribution'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Watch This Video To Crack Any Stats Interview For Data Scientist- Understanding PDF,PMF and CDF',
#      'description': 'In thiss video we will learn about different type sof distirbution and difference between pm,pdf and cdf\nIn mathematics, the derivative of a function of a real variable measures the sensitivity to change of the function value with respect to a change in its argument. Derivatives are a fundamental tool of calculus.\n\nBest Affordable Data Science Course From Pwskills(6-7 Months)\n\nImpact Batch:- Data-Science-Masters (Full Stack Data Science)\n1. Data Science Masters Hindi: https://bit.ly/3CKX1od (Hindi)\n2. Data Science Masters English: https://bit.ly/3iEjWuH (English)\n------------------------------------------------------------------------------------------------\nCheck Out My Other Playlist\nPython Playlist:\nPython In English:https://www.youtube.com/watch?v=bPrmA1SEN2k&list=PLZoTAELRMXVNUL99R4bDlVYsncUNvwUBB\n\nPython In Hindi: https://www.youtube.com/watch?v=MJd9d9Mpxg0&list=PLTDARY42LDV4qqiJd1Z1tShm3mp9-rP4v\n\nStats Playlist: \nEnglish 7 Days Statistics Live Session :https://www.youtube.com/watch?v=11unm2hmvOQ&list=PLZoTAELRMXVMgtxAboeAx-D9qbnY94Yay\nHindi: Stats Playlist: https://www.youtube.com/watch?v=7y3XckjaVOw&list=PLTDARY42LDV6YHSRo669_uDDGmUEmQnDJ\n\nComplete ML Playlist: https://www.youtube.com/watch?v=bPrmA1SEN2k&list=PLZoTAELRMXVPBTrWtJkn3wWQxZkmTXGwe\n\nHindi: ML Playlist: https://www.youtube.com/watch?v=7uwa9aPbBRU&list=PLTDARY42LDV7WGmlzZtY-w9pemyPrKNUZ\n5 DaysLive Deep Learning Playlist: https://www.youtube.com/watch?v=8arGWdq_KL0&list=PLZoTAELRMXVPiyueAqA_eQnsycC_DSBns\n\nComplete Deep Learning Playlist: \nhttps://www.youtube.com/watch?v=YFNKnUhm_-s&list=PLZoTAELRMXVPGU70ZGsckrMdr0FteeRUi'},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '9044',
#     'likeCount': '490',
#     'favoriteCount': '0',
#     'commentCount': '18'}},
#   {'kind': 'youtube#video',
#    'etag': 'U_UXadRDbYlXPexz9cLiiigXclw',
#    'id': 'sqDBEyfRPo8',
#    'snippet': {'publishedAt': '2023-02-21T14:40:53Z',
#     'channelId': 'UCNU_lfiiWBdtULKOw6X0Dig',
#     'title': 'What Is Derivatives In  Calculus In Layman Terms?',
#     'description': 'In mathematics, the derivative of a function of a real variable measures the sensitivity to change of the function value with respect to a change in its argument. Derivatives are a fundamental tool of calculus.\n\nBest Affordable Data Science Course From Pwskills(6-7 Months)\n\nImpact Batch:- Data-Science-Masters (Full Stack Data Science)\n1. Data Science Masters Hindi: https://bit.ly/3CKX1od (Hindi)\n2. Data Science Masters English: https://bit.ly/3iEjWuH (English)\n------------------------------------------------------------------------------------------------\nCheck Out My Other Playlist\nPython Playlist:\nPython In English:https://www.youtube.com/watch?v=bPrmA1SEN2k&list=PLZoTAELRMX

#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '2408',
#     'likeCount': '113',
#     'favoriteCount': '0',
#     'commentCount': '9'}},
#   {'kind': 'youtube#video',
#    'etag': 'jsENMpA_C8ZRUd4Xfv4UYvcqXJ8',
#    'id': 'y2jLcXlgCXk',
#    'snippet': {'publishedAt': '2023-02-20T14:24:15Z',
#     'channelId': 'UCNU_lfiiWBdtULKOw6X0Dig',
#     'title': 'How Prakhar Cracked Multiple Job Offers In Data Science',
#     'description': 'Best Affordable Data Science Course From Pwskills(6-7 Months)\n\nImpact Batch:- Data-Science-Masters (Full Stack Data Science)\n1. Data Science Masters Hindi: https://bit.ly/3CKX1od (Hindi)\n2. Data Science Masters English: https://bit.ly/3iEjWuH (English)\n------------------------------------------------------------------------------------------------\nCheck Out My Other Playlist\nPython Playlist:\nPython In English:https://www.youtube.com/watch?v=bPrmA1SEN2k&list=PLZoTAELRMXVNUL99R4bDlVYsncUNvwUBB\n\nPython In Hindi: https://www.youtube.com/watch?v=MJd9d9Mpxg0&list=PLTDARY42LDV4qqiJd1Z1tShm3mp9-rP4v\n\nStats Playlist: \nEnglish 7 Days Statistics Live Session :https://www.youtube.com/watch?v=11unm2hmvOQ&list=PLZoTAELRMXVMgtxAboeAx-D9qbnY94Yay\nHindi: Stats Playlist: https://www.youtube.com/watch?v=7y3XckjaVOw&list=PLTDARY42LDV6YHSRo669_uDDGmUEmQnDJ\n\nComplete ML Playlist: https://www.youtube.com/watch?v=bPrmA1SEN2k&list=PLZoTAELRMXVPBTrWtJkn3wWQxZkmTXGwe\n\nHindi: ML Playlist: https://www.youtube.com/watch?v=7uwa9aPbBRU&list=PLTDARY42LDV7WGmlzZtY-w9pemyPrKNUZ\n5 DaysLive Deep Learning Playlist: https://www.youtube.com/watch?v=8arGWdq_KL0&list=PLZoTAELRMXVPiyueAqA_eQnsycC_DSBns\n\nComplete Deep Learning Playlist: \nhttps://www.youtube.com/watch?v=YFNKnUhm_-s&list=PLZoTAELRMXVPGU70ZGsckrMdr0FteeRUi',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/y2jLcXlgCXk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/y2jLcXlgCXk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/y2jLcXlgCXk/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/y2jLcXlgCXk/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/y2jLcXlgCXk/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Krish Naik',
#     'tags': ['yt:cc=on',
#      'data science tutorials',
#      'how to crack data science jobs',
#      'how to crack machine learning jobs',
#      'depp learning interview questions',
#      'krish naik machine learning'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'How Prakhar Cracked Multiple Job Offers In Data Science',
#      'description': 'Best Affordable Data Science Course From Pwskills(6-7 Months)\n\nImpact Batch:- Data-Science-Masters (Full Stack Data Science)\n1. Data Science Masters Hindi: https://bit.ly/3CKX1od (Hindi)\n2. Data Science Masters English: https://bit.ly/3iEjWuH (English)\n------------------------------------------------------------------------------------------------\nCheck Out My Other Playlist\nPython Playlist:\nPython In English:https://www.youtube.com/watch?v=bPrmA1SEN2k&list=PLZoTAELRMXVNUL99R4bDlVYsncUNvwUBB\n\nPython In Hindi: https://www.youtube.com/watch?v=MJd9d9Mpxg0&list=PLTDARY42LDV4qqiJd1Z1tShm3mp9-rP4v\n\nStats Playlist: \nEnglish 7 Days Statistics Live Session :https://www.youtube.com/watch?v=11unm2hmvOQ&list=PLZoTAELRMXVMgtxAboeAx-D9qbnY94Yay\nHindi: Stats Playlist: https://www.youtube.com/watch?v=7y3XckjaVOw&list=PLTDARY42LDV6YHSRo669_uDDGmUEmQnDJ\n\nComplete ML Playlist: https://www.youtube.com/watch?v=bPrmA1SEN2k&list=PLZoTAELRMXVPBTrWtJkn3wWQxZkmTXGwe\n\nHindi: ML Playlist: https://www.youtube.com/watch?v=7uwa9aPbBRU&list=PLTDARY42LDV7WGmlzZtY-w9pemyPrKNUZ\n5 DaysLive Deep Learning Playlist: https://www.youtube.com/watch?v=8arGWdq_KL0&list=PLZoTAELRMXVPiyueAqA_eQnsycC_DSBns\n\nComplete Deep Learning Playlist: \nhttps://www.youtube.com/watch?v=YFNKnUhm_-s&list=PLZoTAELRMXVPGU70ZGsckrMdr0FteeRUi'},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '6925',
#     'likeCount': '208',
#     'favoriteCount': '0',
#     'commentCount': '22'}},
#   {'kind': 'youtube#video',
#    'etag': 'Xhjt7_tR3gp3s9zgTurp5tlpOUI',
#    'id': 'Tyf1XrbDNrs',
#    'snippet': {'publishedAt': '2023-02-16T06:22:29Z',
#     'channelId': 'UCNU_lfiiWBdtULKOw6X0Dig',
#     'title': 'How Jaiyesh Cracked Data Science Job In Siemens From Petroleum Engineering @iNeuroniNtelligence',
#     'description': 'Cracking a data science job becomes easy when you follow a disciplined routine and process. Hear out Jaiyesh Story how he cracked data sscience job in Siemens\nTimestamp:\n00:00:00 Introduction\n00:00:43 Brief Intro And Early Education\n00:03:03 Interview Experience And Questions Asked\n00:04:56 Experience Of Learning In  @iNeuroniNtelligence  \n00:06:09 Resume Preparation\n00:07:47 How did You Apply For The Job\n00:09:04 Day To Day Work In Siemens\n00:11:06 Challenge Faced During Preparation\n00:12:02 Rapid Fire\n----------------------------------------------------------------------------------------------\nBest Affordable Data Science Course From Pwskills(6-7 Months)\n\nImpact Batch:- Data-Science-Masters (Full Stack Data Science)\n1. Data Science Masters Hindi: https://bit.ly/3CKX1od (Hindi)\n2. Data Science Masters English: https://bit.ly/3iEjWuH (English)\n------------------------------------------------------------------------------------------------\nCheck Out My Other Playlist\nPython Playlist:\nPython In English:https://www.youtube.com/watch?v=bPrmA1SEN2k&list=PLZoTAELRMXVNUL99R4bDlVYsncUNvwUBB\n\nPython In Hindi: https://www.youtube.com/watch?v=MJd9d9Mpxg0&list=PLTDARY42LDV4qqiJd1Z1tShm3mp9-rP4v\n\nStats Playlist: \nEnglish 7 Days Statistics Live Session :https://www.youtube.com/watch?v=11unm2hmvOQ&list=PLZoTAELRMXVMgtxAboeAx-D9qbnY94Yay\nHindi: Stats Playlist: https://www.youtube.com/watch?v=7y3XckjaVOw&list=PLTDARY42LDV6YHSRo669_uDDGmUEmQnDJ\n\nComplete ML Playlist: https://www.youtube.com/watch?v=bPrmA1SEN2k&list=PLZoTAELRMXVPBTrWtJkn3wWQxZkmTXGwe\n\nHindi: ML Playlist: https://www.youtube.com/watch?v=7uwa9aPbBRU&list=PLTDARY42LDV7WGmlzZtY-w9pemyPrKNUZ\n5 DaysLive Deep Learning Playlist: https://www.youtube.com/watch?v=8arGWdq_KL0&list=PLZoTAELRMXVPiyueAqA_eQnsycC_DSBns\n\nComplete Deep Learning Playlist: \nhttps://www.youtube.com/watch?v=YFNKnUhm_-s&list=PLZoTAELRMXVPGU70ZGsckrMdr0FteeRUi',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Tyf1XrbDNrs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Tyf1XrbDNrs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Tyf1XrbDNrs/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Tyf1XrbDNrs/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Tyf1XrbDNrs/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Krish Naik',
#     'tags': ['yt:cc=on',
#      'how to crack data science jobs',
#      'data science jobs in faang',
#      'can we crack data science from other domain',
#      'non tech to data science'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 

#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '5157',
#     'likeCount': '145',
#     'favoriteCount': '0',
#     'commentCount': '24'}},
#   {'kind': 'youtube#video',
#    'etag': 'mRu7R18q9kpv7ztLNpYiRj8AbYM',
#    'id': '0vnaw8soiO4',
#    'snippet': {'publishedAt': '2023-02-13T11:47:54Z',
#     'channelId': 'UCNU_lfiiWBdtULKOw6X0Dig',
#     'title': 'How Raghav Got 6 Offers In Data Science Coming From Non Technical Domain @iNeuroniNtelligence',
#     'description': "#fsdsbootcamp\nRaghav's Linkedin : https://www.linkedin.com/in/raghavbakshi19/\nBest Affordable Data Science Course From Pwskills(6-7 Months)\n\nImpact Batch:- Data-Science-Masters (Full Stack Data Science)\n1. Data Science Masters Hindi: https://bit.ly/3CKX1od (Hindi)\n2. Data Science Masters English: https://bit.ly/3iEjWuH (English)\n------------------------------------------------------------------------------------------------\nCheck Out My Other Playlist\nPython Playlist:\nPython In English:https://www.youtube.com/watch?v=bPrmA1SEN2k&list=PLZoTAELRMXVNUL99R4bDlVYsncUNvwUBB\n\nPython In Hindi: https://www.youtube.com/watch?v=MJd9d9Mpxg0&list=PLTDARY42LDV4qqiJd1Z1tShm3mp9-rP4v\n\nStats Playlist: \nEnglish 7 Days Statistics Live Session :https://www.youtube.com/watch?v=11unm2hmvOQ&list=PLZoTAELRMXVMgtxAboeAx-D9qbnY94Yay\nHindi: Stats Playlist: https://www.youtube.com/watch?v=7y3XckjaVOw&list=PLTDARY42LDV6YHSRo669_uDDGmUEmQnDJ\n\nComplete ML Playlist: https://www.youtube.com/watch?v=bPrmA1SEN2k&list=PLZoTAELRMXVPBTrWtJkn3wWQxZkmTXGwe\n\nHindi: ML Playlist: https://www.youtube.com/watch?v=7uwa9aPbBRU&list=PLTDARY42LDV7WGmlzZtY-w9pemyPrKNUZ\n5 DaysLive Deep Learning Playlist: https://www.youtube.com/watch?v=8arGWdq_KL0&list=PLZoTAELRMXVPiyueAqA_eQnsycC_DSBns\n\nComplete Deep Learning Playlist: \nhttps://www.youtube.com/watch?v=YFNKnUhm_-s&list=PLZoTAELRMXVPGU70ZGsckrMdr0FteeRUi",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0vnaw8soiO4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0vnaw8soiO4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0vnaw8soiO4/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/0vnaw8soiO4/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/0vnaw8soiO4/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Krish Naik',
#     'tags': ['yt:cc=on',
#      'how to tranition into data science',
#      'how to transition into machine learning',
#      'data science jobs',
#      'how to clear product based companies',
#      'krish naik machine learning'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'How Raghav Got 6 Offers In Data Science Coming From Non Technical Domain @iNeuroniNtelligence',
#      'description': "#fsdsbootcamp\nRaghav's Linkedin : https://www.linkedin.com/in/raghavbakshi19/\nBest Affordable Data Science Course From Pwskills(6-7 Months)\n\nImpact Batch:- Data-Science-Masters (Full Stack Data Science)\n1. Data Science Masters Hindi: https://bit.ly/3CKX1od (Hindi)\n2. Data Science Masters English: https://bit.ly/3iEjWuH (English)\n------------------------------------------------------------------------------------------------\nCheck Out My Other Playlist\nPython Playlist:\nPython In English:https://www.youtube.com/watch?v=bPrmA1SEN2k&list=PLZoTAELRMXVNUL99R4bDlVYsncUNvwUBB\n\nPython In Hindi: https://www.youtube.com/watch?v=MJd9d9Mpxg0&list=PLTDARY42LDV4qqiJd1Z1tShm3mp9-rP4v\n\nStats Playlist: \nEnglish 7 Days Statistics Live Session :https://www.youtube.com/watch?v=11unm2hmvOQ&list=PLZoTAELRMXVMgtxAboeAx-D9qbnY94Yay\nHindi: Stats Playlist: https://www.youtube.com/watch?v=7y3XckjaVOw&list=PLTDARY42LDV6YHSRo669_uDDGmUEmQnDJ\n\nComplete ML Playlist: https://www.youtube.com/watch?v=bPrmA1SEN2k&list=PLZoTAELRMXVPBTrWtJkn3wWQxZkmTXGwe\n\nHindi: ML Playlist: https://www.youtube.com/watch?v=7uwa9aPbBRU&list=PLTDARY42LDV7WGmlzZtY-w9pemyPrKNUZ\n5 DaysLive Deep Learning Playlist: https://www.youtube.com/watch?v=8arGWdq_KL0&list=PLZoTAELRMXVPiyueAqA_eQnsycC_DSBns\n\nComplete Deep Learning Playlist: \nhttps://www.youtube.com/watch?v=YFNKnUhm_-s&list=PLZoTAELRMXVPGU70ZGsckrMdr0FteeRUi"},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '14428',
#     'likeCount': '484',
#     'favoriteCount': '0',
#     'commentCount': '34'}},
#   {'kind': 'youtube#video',
#    'etag': 'qaelBjsgtiGGWGid-Vho7z0almY',
#    'id': 'AcAmDZcmVMM',
#    'snippet': {'publishedAt': '2023-02-12T06:25:52Z',
#     'channelId': 'UCNU_lfiiWBdtULKOw6X0Dig',
#     'title': 'Sucessful Transition Story From Mechanical Eng ,UPSC Aspirant To Data Analyst Apprentice At Google',
#     'description': 'Hariharan Linkedin Id: https://www.linkedin.com/in/hariharan14399/\nTimestamp\n00:00:00 - Introduction\n00:00:56 - Education Background And UPSC Journey And getting into Google\n00:07:06 - Questions Asked in Google Interview\n00:10:25 - Overcominh Challenge While Learning\n00:13:14- Advice to Others\n-----------------------------------------------------------------------------------------------\nBest Affordable Data Science Course From Pwskills(6-7 Months)\n\nImpact Batch:- Data-Science-Masters (Full Stack Data Science)\n1. Data Science Masters Hindi: https://bit.ly/3CKX1od (Hindi)\n2. Data Science Masters English: https://bit.ly/3iEjWuH (English)\n------------------------------------------------------------------------------------------------\nCheck Out My Other Playlist\nPython Playlist:\nPython In English:https://www.youtube.com/watch?v=bPrmA1SEN2k&list=PLZoTAELRMXVNUL99R4bDlVYsncUNvwUBB\n\nPython In Hindi: https://www.youtube.com/watch?v=MJd9d9Mpxg0&list=PLTDARY42LDV4qqiJd1Z1tShm3mp9-rP4v\n\nStats Playlist: \nEnglish 7 Days Statistics Live Session :https://www.youtube.com/watch?v=11unm2hmvOQ&list=PLZoTAELRMXVMgtxAboeAx-D9qbnY94Yay\nHindi: Stats Playlist: https://www.youtube.com/watch?v=7y3XckjaVOw&list=PLTDARY42LDV6YHSRo669_uDDGmUEmQnDJ\n\nComplete ML Playlist: https://www.youtube.com/watch?v=bPrmA1SEN2k&list=PLZoTAELRMXVPBTrWtJkn3wWQxZkmTXGwe\n\nHindi: ML Playlist: https://www.youtube.com/watch?v=7uwa9aPbBRU&list=PLTDARY42LDV7WGmlzZtY-w9pemyPrKNUZ\n5 DaysLive Deep Learning Playlist: https://www.youtube.com/watch?v=8arGWdq_KL0&list=PLZoTAELRMXVPiyueAqA_eQnsycC_DSBns\n\nComplete Deep Learning Playlist: \nhttps://www.youtube.com/watch?v=YFNKnUhm_-s&list=PLZoTAELRMXVPGU70ZGsckrMdr0FteeRUi',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AcAmDZcmVMM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AcAmDZcmVMM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AcAmDZcmVMM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/AcAmDZcmVMM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/AcAmDZcmVMM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Krish Naik',
#     'tags': ['yt:cc=on',
#      'how to get datanalyst job at google',
#      'how to become data scientisst in google',
#      'data science jobs',
#      'machin elearning jobs',
#      'krish naik machine learning',
#      'krish naik deep learning'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Sucessful Transition Story From Mechanical Eng ,UPSC Aspirant To Data Analyst Apprentice At Google',
#      'description': 'Hariharan Linkedin Id: https://www.linkedin.com/in/hariharan14399/\nTimestamp\n00:00:00 - Introduction\n00:00:56 - Education Background And UPSC Journey And getting into Google\n00:07:06 - Questions Asked in Google Interview\n00:10:25 - Overcominh Challenge While Learning\n00:13:14- Advice to Others\n-----------------------------------------------------------------------------------------------\nBest Affordable Data Science Course From Pwskills(6-7 Months)\n\nImpact Batch:- Data-Science-Masters (Full Stack Data Science)\n1. Data Science Masters Hindi: https://bit.ly/3CKX1od (Hindi)\n2. Data Science Masters English: https://bit.ly/3iEjWuH (English)\n------------------------------------------------------------------------------------------------\nCheck Out My Other Playlist\nPython Playlist:\nPython In English:https://www.youtube.com/watch?v=bPrmA1SEN2k&list=PLZoTAELRMXVNUL99R4bDlVYsncUNvwUBB\n\nPython In Hindi: https://www.youtube.com/watch?v=MJd9d9Mpxg0&list=PLTDARY42LDV4qqiJd1Z1tShm3mp9-rP4v\n\nStats Playlist: \nEnglish 7 Days Statistics Live Session :https://www.youtube.com/watch?v=11unm2hmvOQ&list=PLZoTAELRMXVMgtxAboeAx-D9qbnY94Yay\nHindi: Stats Playlist: https://www.youtube.com/watch?v=7y3XckjaVOw&list=PLTDARY42LDV6YHSRo669_uDDGmUEmQnDJ\n\nComplete ML Playlist: https://www.youtube.com/watch?v=bPrmA1SEN2k&list=PLZoTAELRMXVPBTrWtJkn3wWQxZkmTXGwe\n\nHindi: ML Playlist: https://www.youtube.com/watch?v=7uwa9aPbBRU&list=PLTDARY42LDV7WGmlzZtY-w9pemyPrKNUZ\n5 DaysLive Deep Learning Playlist: https://www.youtube.com/watch?v=8arGWdq_KL0&list=PLZoTAELRMXVPiyueAqA_eQnsycC_DSBns\n\nComplete Deep Learning Playlist: \nhttps://www.youtube.com/watch?v=YFNKnUhm_-s&list=PLZoTAELRMXVPGU70ZGsckrMdr0FteeRUi'},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '5962',
#     'likeCount': '175',
#     'favoriteCount': '0',
#     'commentCount': '11'}},
#   {'kind': 'youtube#video',
#    'etag': 'Y9VQfDQYpKwntJBdZPePPYGHCm0',
#    'id': 'MQDqGpmB_kQ',
#    'snippet': {'publishedAt': '2023-02-09T14:31:45Z',
#     'channelId': 'UCNU_lfiiWBdtULKOw6X0Dig',
#     'title': 'Can We Earn More From FreeLancing Than Full time Jobs? Steps To Start Your Free Lancing Career',
#     'description': 'Starting a freelancing career can be an exciting and fulfilling way to work on your own terms and build a stable income. To begin, start by identifying your skills and what services you can offer as a freelancer. Next, create a portfolio that showcases your work and set up profiles on popular freelancing platforms such as Upwork or Freelancer. Network and market yourself by reaching out to potential clients and collaborating with others in your industry. Additionally, make sure to stay organized and manage your time effectively, as freelancing requires discipline and self-motivation.\n-----------------------------------------------------------------------------------------------\nBest Affordable Data Science Course From Pwskills(6-7 Months)\n\nImpact Batch:- Data-Science-Masters (Full Stack Data Science)\n1. Data Science Masters Hindi: https://bit.ly/3CKX1od (Hindi)\n2. Data Science Masters English: https://bit.ly/3iEjWuH (English)\n------------------------------------------------------------------------------------------------\nCheck Out My Other Playlist\nPython Playlist:\nPython In English:https://www.youtube.com/watch?v=bPrmA1SEN2k&list=PLZoTAELRMXVNUL99R4bDlVYsncUNvwUBB\n\nPython In Hindi: https://www.youtube.com/watch?v=MJd9d9Mpxg0&list=PLTDARY42LDV4qqiJd1Z1tShm3mp9-rP4v\n\nStats Playlist: \nEnglish 7 Days Statistics Live Session :https://www.youtube.com/watch?v=11unm2hmvOQ&list=PLZoTAELRMXVMgtxAboeAx-D9qbnY94Yay\nHindi: Stats Playlist: https://www.youtube.com/watch?v=7y3XckjaVOw&list=PLTDARY42LDV6YHSRo669_uDDGmUEmQnDJ\n\nComplete ML Playlist: https://www.youtube.com/watch?v=bPrmA1SEN2k&list=PLZoTAELRMXVPBTrWtJkn3wWQxZkmTXGwe\n\nHindi: ML Playlist: https://www.youtube.com/watch?v=7uwa9aPbBRU&list=PLTDARY42LDV7WGmlzZtY-w9pemyPrKNUZ\n5 DaysLive Deep Learning Playlist: https://www.youtube.com/watch?v=8arGWdq_KL0&list=PLZoTAELRMXVPiyueAqA_eQnsycC_DSBns\n\nComplete Deep Learning Playlist: \nhttps://www.youtube.com/watch?v=YFNKnUhm_-s&list=PLZoTAELRMXVPGU70ZGsckrMdr0FteeRUi',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/MQDqGpmB_kQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/MQDqGpmB_kQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/MQDqGpmB_kQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/MQDqGpmB_kQ/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/MQDqGpmB_kQ/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Krish Naik',
#     'tags': ['yt:cc=on',
#      'freelancing',
#      'starting a freelancing career',
#      'freelancer tips',
#      'freelancing for beginners',
#      'how to be a successful freelancer',
#      'freelance marketplaces',
#      'freelancing as a side hustle',
#      'freelancing income',
#      'freelancing skills',
#      'freelance portfolio.'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
# ...
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Black Friday Sales 50% off On All Courses And Mobile App Announcement @iNeuroniNtelligence',
#      'description': 'As we have come to the year end all the courses in ineuron will be available at 50% off. Utilize this opportunity and share it with your friends. \n\nVisit: https://ineuron.ai\nUse coupon code Krish50\ncheck out the ineuron mobile app : \nhttps://lnkd.in/g5SjRm3J\n\nJoin our discord channel in case of any queries\r\nhttps://discord.gg/wgrEJtwabt\r\nFor more info you can reach out to our team via the numbers given below,\r\n\r\n+919538303385\r\n+918660034247\r\n+918788503778\r\n+919880055539'},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '13958',
#     'likeCount': '157',
#     'favoriteCount': '0',
#     'commentCount': '65'}},
#   {'kind': 'youtube#video',
#    'etag': '7i2QwEXV1m1KsIO4UeRpprYiXME',
#    'id': 'VbaJ7eL9qFM',
#    'snippet': {'publishedAt': '2022-11-17T15:30:06Z',
#     'channelId': 'UCNU_lfiiWBdtULKOw6X0Dig',
#     'title': 'All Possible Ways To Apply Jobs In Data Science Industry',
#     'description': 'Last 4 days for the launch of  new Machine Learning Bootcamp\n\nStart Date:\n27th November 2022\nClass Timings:\n8 - 11PM IST Tuesday & Thursday\nDoubt Session:\n11PM - 12AM IST Tuesday & Thursday\n\n Machine Learning Bootcamp: https://bit.ly/3TkfbUp\n\nUse the above link to avail 30% off\n\nJoin our discord channel in case of any queries\nhttps://discord.gg/wgrEJtwabt\nFor more info you can reach out to our team via the numbers given below,\n\n+919538303385\n+918660034247\n+918788503778\n+919880055539',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VbaJ7eL9qFM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/VbaJ7eL9qFM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/VbaJ7eL9qFM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/VbaJ7eL9qFM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/VbaJ7eL9qFM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Krish Naik',
#     'tags': ['yt:cc=on',
#      'data science job search',
#      'machine learning jobs',
#      'deep learning jobs',
#      'how to crack data science interview'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'All Possible Ways To Apply Jobs In Data Science Industry',
#      'description': 'Last 4 days for the launch of  new Machine Learning Bootcamp\n\nStart Date:\n27th November 2022\nClass Timings:\n8 - 11PM IST Tuesday & Thursday\nDoubt Session:\n11PM - 12AM IST Tuesday & Thursday\n\n Machine Learning Bootcamp: https://bit.ly/3TkfbUp\n\nUse the above link to avail 30% off\n\nJoin our discord channel in case of any queries\nhttps://discord.gg/wgrEJtwabt\nFor more info you can reach out to our team via the numbers given below,\n\n+919538303385\n+918660034247\n+918788503778\n+919880055539'},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '29002',
#     'likeCount': '1052',
#     'favoriteCount': '0',
#     'commentCount': '53'}},
#   {'kind': 'youtube#video',
#    'etag': 'vKzq0GIeAzJ_5thdGZvxCLgt3Y4',
#    'id': 'VpkM6IiaJVU',
#    'snippet': {'publishedAt': '2022-11-12T14:29:11Z',
#     'channelId': 'UCNU_lfiiWBdtULKOw6X0Dig',
#     'title': 'Companies That Are Hiring Aggressively For Data Science or Data Analytics Roles',
#     'description': 'Last 1 day for the launch of  new Full Stack Data Analytics 2.0 with Placement Assistance\n#datasciencecareer #jobs \nDate : 12th November\nTiming :3pm to 6pm\n\n Course link: https://bit.ly/3rVaNPm\n\nUse the above link to avail 30% off\n\nJoin our discord channel in case of any queries\nhttps://discord.gg/wgrEJtwabt\nFor more info you can reach out to our team via the numbers given below,\n\n+919538303385\n+918660034247\n+918788503778\n+919880055539',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VpkM6IiaJVU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/VpkM6IiaJVU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/VpkM6IiaJVU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/VpkM6IiaJVU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/VpkM6IiaJVU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Krish Naik',
#     'tags': ['yt:cc=on',
#      'krish naik machine learning',
#      'tredence analytics career page',
#      'fractal analytics data science hiring',
#      'E&Y data science hiring',
#      'KPMG data science hiring',
#      'how to clear data science interviews'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Companies That Are Hiring Aggressively For Data Science or Data Analytics Roles',
#      'description': 'Last 1 day for the launch of  new Full Stack Data Analytics 2.0 with Placement Assistance\n#datasciencecareer #jobs \nDate : 12th November\nTiming :3pm to 6pm\n\n Course link: https://bit.ly/3rVaNPm\n\nUse the above link to avail 30% off\n\nJoin our discord channel in case of any queries\nhttps://discord.gg/wgrEJtwabt\nFor more info you can reach out to our team via the numbers given below,\n\n+919538303385\n+918660034247\n+918788503778\n+919880055539'},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '63733',
#     'likeCount': '2359',
#     'favoriteCount': '0',
#     'commentCount': '101'}},
#   {'kind': 'youtube#video',
#    'etag': 'jtrAuLOfuCYewEWfQBMhgtoJNGM',
#    'id': 'UyKjK0DnTaE',
#    'snippet': {'publishedAt': '2022-11-11T14:43:24Z',
#     'channelId': 'UCNU_lfiiWBdtULKOw6X0Dig',
#     'title': 'Best MLOPS Architecture For Data Science Projects',
#     'description': 'Check out best courses in ineuron With 30% off on this festive offer\nDISCOUNT CODE - KRISH30\nDISCOUNT LINK:-\nCheck All the Courses Below\nMachine Learning Bootcamp: https://bit.ly/3TkfbUp\nFull Stack Data Analytics 2.0 With Placement Assistance: https://bit.ly/3rVaNPm\n\nTech Neuron: https://bit.ly/3rls7Np\nFSDS BootCamp 2.0 With Job guaranteed: https://bit.ly/3qalRaF\nData Science Industry Ready Projects: https://bit.ly/3qmKGAe\nBig Data Job Guaranteed 2.0: https://bit.ly/3egbuQf\nVisit the iNeuron website:- https://ineuron.ai/\n\nJoin our discord channel in case of any queries\nhttps://discord.gg/wgrEJtwabt\nFor more info you can reach out to our team via the numbers given below,\n\n+919538303385\n+918660034247\n+918788503778\n+919880055539',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UyKjK0DnTaE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UyKjK0DnTaE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UyKjK0DnTaE/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/UyKjK0DnTaE/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/UyKjK0DnTaE/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Krish Naik',
#     'tags': ['yt:cc=on',
#      'data science end to end projects',
#      'mlops data science projects',
#      'ineuron data science',
#      'machine learning data science',
#      'krish naik machine learning'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Best MLOPS Architecture For Data Science Projects',
#      'description': 'Check out best courses in ineuron With 30% off on this festive offer\nDISCOUNT CODE - KRISH30\nDISCOUNT LINK:-\nCheck All the Courses Below\nMachine Learning Bootcamp: https://bit.ly/3TkfbUp\nFull Stack Data Analytics 2.0 With Placement Assistance: https://bit.ly/3rVaNPm\n\nTech Neuron: https://bit.ly/3rls7Np\nFSDS BootCamp 2.0 With Job guaranteed: https://bit.ly/3qalRaF\nData Science Industry Ready Projects: https://bit.ly/3qmKGAe\nBig Data Job Guaranteed 2.0: https://bit.ly/3egbuQf\nVisit the iNeuron website:- https://ineuron.ai/\n\nJoin our discord channel in case of any queries\nhttps://discord.gg/wgrEJtwabt\nFor more info you can reach out to our team via the numbers given below,\n\n+919538303385\n+918660034247\n+918788503778\n+919880055539'},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '12188',
#     'likeCount': '361',
#     'favoriteCount': '0',
#     'commentCount': '29'}},
#   {'kind': 'youtube#video',
#    'etag': 'DOB9ONSk0hE06N3H12hQday-zjo',
#    'id': 'cLHM0BNC_No',
#    'snippet': {'publishedAt': '2022-11-10T14:35:17Z',
#     'channelId': 'UCNU_lfiiWBdtULKOw6X0Dig',
#     'title': 'Full Stack Data Analytics 2.0 Live Batch- Best Course For Data Analyst',
#     'description': 'Last 2 days for the launch of  new Full Stack Data Analytics 2.0 with Placement Assistance\n\nDate : 12th November\nTiming :3pm to 6pm\n\n Course link: https://bit.ly/3rVaNPm\n\nUse the above link to avail 30% off\n\nJoin our discord channel in case of any queries\nhttps://discord.gg/wgrEJtwabt\nFor more info you can reach out to our team via the numbers given below,\n\n+919538303385\n+918660034247\n+918788503778\n+919880055539',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cLHM0BNC_No/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/cLHM0BNC_No/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/cLHM0BNC_No/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/cLHM0BNC_No/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/cLHM0BNC_No/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Krish Naik',
#     'tags': ['yt:cc=on',
#      'how to become a data analyst',
#      'data analytics course',
#      'ineuron data analyst course'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Full Stack Data Analytics 2.0 Live Batch- Best Course For Data Analyst',
#      'description': 'Last 2 days for the launch of  new Full Stack Data Analytics 2.0 with Placement Assistance\n\nDate : 12th November\nTiming :3pm to 6pm\n\n Course link: https://bit.ly/3rVaNPm\n\nUse the above link to avail 30% off\n\nJoin our discord channel in case of any queries\nhttps://discord.gg/wgrEJtwabt\nFor more info you can reach out to our team via the numbers given below,\n\n+919538303385\n+918660034247\n+918788503778\n+919880055539'},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '12205',
#     'likeCount': '195',
#     'favoriteCount': '0',
#     'commentCount': '47'}},
#   {'kind': 'youtube#video',
#    'etag': 'wR5l-RbKStlyD7r-Ie7B0mpjjcA',
#    'id': 'yrdPuJO31BE',
#    'snippet': {'publishedAt': '2022-11-08T15:57:00Z',
#     'channelId': 'UCNU_lfiiWBdtULKOw6X0Dig',
#     'title': 'When Are We Launching iNeuron Mobile App- Both IOS And Android',
#     'description': 'Last 3 days for the launch of  new Full Stack Data Analytics 2.0 with Placement Assistance\n\nDate : 12th November\nTiming :3pm to 6pm\n\n Course link: https://bit.ly/3rVaNPm\n\nUse the above link to avail 30% off\n\nJoin our discord channel in case of any queries\nhttps://discord.gg/wgrEJtwabt\nFor more info you can reach out to our team via the numbers given below,\n\n+919538303385\n+918660034247\n+918788503778\n+919880055539',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yrdPuJO31BE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yrdPuJO31BE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yrdPuJO31BE/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/yrdPuJO31BE/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/yrdPuJO31BE/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Krish Naik',
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'When Are We Launching iNeuron Mobile App- Both IOS And Android',
#      'description': 'Last 3 days for the launch of  new Full Stack Data Analytics 2.0 with Placement Assistance\n\nDate : 12th November\nTiming :3pm to 6pm\n\n Course link: https://bit.ly/3rVaNPm\n\nUse the above link to avail 30% off\n\nJoin our discord channel in case of any queries\nhttps://discord.gg/wgrEJtwabt\nFor more info you can reach out to our team via the numbers given below,\n\n+919538303385\n+918660034247\n+918788503778\n+919880055539'},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '83900',
#     'likeCount': '272',
#     'favoriteCount': '0',
#     'commentCount': '59'}},
#   {'kind': 'youtube#video',
#    'etag': 'Zj1oZucl8aQSh4CpEsIRfFKxoA4',
#    'id': 'X9i8TtfaI8A',
#    'snippet': {'publishedAt': '2022-11-06T16:22:21Z',
#     'channelId': 'UCNU_lfiiWBdtULKOw6X0Dig',
#     'title': 'Is Recession Coming? What You Should Do?',
#     'description': 'Visit Neuro Lab: https://neurolab.ineuron.ai/\nJoin our discord channel in case of any queries\nhttps://discord.gg/wgrEJtwabt\n#datasciencecareer \nCheck out best courses in ineuron With 30% off on this festive offer\nDISCOUNT CODE - KRISH30\nDISCOUNT LINK:-\nCheck All the Courses Below\nMachine Learning Bootcamp: https://bit.ly/3TkfbUp\nFull Stack Data Analytics 2.0 With Placement Assistance: https://bit.ly/3rVaNPm\n\nTech Neuron: https://bit.ly/3rls7Np\nFSDS BootCamp 2.0 With Job guaranteed: https://bit.ly/3qalRaF\nData Science Industry Ready Projects: https://bit.ly/3qmKGAe\nBig Data Job Guaranteed 2.0: https://bit.ly/3egbuQf\nVisit the iNeuron website:- https://ineuron.ai/\n\n\nFor more info you can reach out to our team via the numbers given below,\n\n+919538303385\n+918660034247\n+918788503778\n+919880055539',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/X9i8TtfaI8A/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/X9i8TtfaI8A/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/X9i8TtfaI8A/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/X9i8TtfaI8A/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/X9i8TtfaI8A/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Krish Naik',
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Is Recession Coming? What You Should Do?',
#      'description': 'Visit Neuro Lab: https://neurolab.ineuron.ai/\nJoin our discord channel in case of any queries\nhttps://discord.gg/wgrEJtwabt\n#datasciencecareer \nCheck out best courses in ineuron With 30% off on this festive offer\nDISCOUNT CODE - KRISH30\nDISCOUNT LINK:-\nCheck All the Courses Below\nMachine Learning Bootcamp: https://bit.ly/3TkfbUp\nFull Stack Data Analytics 2.0 With Placement Assistance: https://bit.ly/3rVaNPm\n\nTech Neuron: https://bit.ly/3rls7Np\nFSDS BootCamp 2.0 With Job guaranteed: https://bit.ly/3qalRaF\nData Science Industry Ready Projects: https://bit.ly/3qmKGAe\nBig Data Job Guaranteed 2.0: https://bit.ly/3egbuQf\nVisit the iNeuron website:- https://ineuron.ai/\n\n\nFor more info you can reach out to our team via the numbers given below,\n\n+919538303385\n+918660034247\n+918788503778\n+919880055539'},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '127219',
#     'likeCount': '2945',
#     'favoriteCount': '0',
#     'commentCount': '172'}}],
#  'pageInfo': {'totalResults': 50, 'resultsPerPage': 50}}

# %%
def get_video_Details(youtube,Video_ids):
    all_video_details=list()
    for i in range(0,len(Video_ids),50):
        request=youtube.videos().list(
                part='snippet,contentDetails,statistics',
                id=','.join(Video_ids[i:i+50]))
        response=request.execute()

        for j in range(len(response['items'])):
            video_statistics=dict(Title=response['items'][j]['snippet']['title'],
                                 Published_at=response['items'][j]['snippet']['publishedAt'],
                                 #Description=response['items'][j]['snippet']['description'],
                                 views=response['items'][j]['statistics']['viewCount'],
                                 Likes=response['items'][j]['statistics']['likeCount'],
                                 #Comment_count=response['items'][j]['statistics']['commentCount']
                                 
                                 )
             # Check if the 'commentCount' key exists in the dictionary
            if 'commentCount' in response['items'][j]['statistics']:
                video_statistics['Comment'] = response['items'][j]['statistics']['commentCount']
            else:
                video_statistics['Comment'] = None
            all_video_details.append(video_statistics)

    return all_video_details

# %%
video_details=get_video_Details(youtube,Video_ids)

# %%
video_data=pd.DataFrame(video_details)

# %%
video_data
# Out:
#                                                   Title          Published_at  \
# 0                    How ChatGPT Can Be Wrong About Me?  2023-02-27T08:16:20Z
# 1     When Your Kid Doesnt Want You To Work-Just For...  2023-02-24T14:49:47Z
# 2     Changes Is Inevitable And You Need To Change W...  2023-02-24T07:11:12Z
# 3     Watch This Video To Crack Any Stats Interview ...  2023-02-23T12:36:55Z
# 4     What Is Derivatives In  Calculus In Layman Terms?  2023-02-21T14:40:53Z
# ...                                                 ...                   ...
# 1567  Important libraries used in python Data Scienc...  2017-11-26T07:48:27Z
# 1568  Anaconda installation with Packages- Machine L...  2017-11-26T06:16:34Z
# 1569  What is Supervised Machine Learning- Machine L...  2017-11-26T04:50:08Z
# 1570  What is Machine Learning in Data Science- Mach...  2017-11-25T12:27:20Z
# 1571                  Maeri unplugged by Krish and band  2014-06-01T07:20:59Z
#
#        views Likes Comment
# 0       3394   126      26
# 1      14817   559      61
# 2       8217   432      38
# 3       9044   490      18
# 4       2408   113       9
# ...      ...   ...     ...
# 1567   19442   171      15
# 1568   74012   337      37
# 1569   33159   385      16
# 1570  130467   811      46
# 1571    5067   130       8
#
# [1572 rows x 5 columns]

# %%
video_data.dtypes
# Out:
# Title           object
# Published_at    object
# views           object
# Likes           object
# Comment         object
# dtype: object

# %%
video_data['Published_at']=pd.to_datetime(video_data['Published_at']).dt.date
video_data['views']=pd.to_numeric(video_data['views'])
video_data['Likes']=pd.to_numeric(video_data['Likes'])
video_data['Comment']=pd.to_numeric(video_data['Comment'])

# %%
video_data.dtypes
# Out:
# Title            object
# Published_at     object
# views             int64
# Likes             int64
# Comment         float64
# dtype: object

# %%
video_data
# Out:
#                                                   Title Published_at   views  \
# 0                    How ChatGPT Can Be Wrong About Me?   2023-02-27    3394
# 1     When Your Kid Doesnt Want You To Work-Just For...   2023-02-24   14817
# 2     Changes Is Inevitable And You Need To Change W...   2023-02-24    8217
# 3     Watch This Video To Crack Any Stats Interview ...   2023-02-23    9044
# 4     What Is Derivatives In  Calculus In Layman Terms?   2023-02-21    2408
# ...                                                 ...          ...     ...
# 1567  Important libraries used in python Data Scienc...   2017-11-26   19442
# 1568  Anaconda installation with Packages- Machine L...   2017-11-26   74012
# 1569  What is Supervised Machine Learning- Machine L...   2017-11-26   33159
# 1570  What is Machine Learning in Data Science- Mach...   2017-11-25  130467
# 1571                  Maeri unplugged by Krish and band   2014-06-01    5067
#
#       Likes  Comment
# 0       126     26.0
# 1       559     61.0
# 2       432     38.0
# 3       490     18.0
# 4       113      9.0
# ...     ...      ...
# 1567    171     15.0
# 1568    337     37.0
# 1569    385     16.0
# 1570    811     46.0
# 1571    130      8.0
#
# [1572 rows x 5 columns]

# %%
top10_videos=video_data.sort_values(by='views',ascending=False).head(10)

# %%
top10_videos
# Out:
#                                                   Title Published_at    views  \
# 1319                     AI VS ML VS DL VS Data Science   2019-11-26  2462472
# 1437                 How To Learn Data Science Smartly?   2019-08-22  1533583
# 879   Complete Road Map To Be Expert In Python- Foll...   2020-09-18  1481650
# 315   OTT Platform For Education OneNeuron- Educatio...   2021-12-11   734801
# 769   Negotiating Salaries With HR for Any Job Is An...   2020-12-30   629950
# 869   Complete Road Map To Prepare NLP-Follow This V...   2020-09-25   585373
# 984   Live- Implementation of End To End Kaggle Mach...   2020-06-30   547909
# 1428  How To Learn Data Science by Self Study and Fo...   2019-08-27   522771
# 298    Learning Data Science In 2022- Step By Step Plan   2022-01-04   450329
# 291   Complete Roadmap For Becoming A Blockchain Dev...   2022-01-11   447020
#
#       Likes  Comment
# 1319  59632   1614.0
# 1437  49497   1304.0
# 879   16588    437.0
# 315     961    114.0
# 769   15042    562.0
# 869    4219    141.0
# 984   13036    649.0
# 1428  27355   1013.0
# 298    7009    212.0
# 291    2129     88.0

# %%
gt=sns.barplot(x='views',y='Title',data=top10_videos)
# Out:
# E:\DataScience projects\Virtual_demo\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128557 (\N{LOUDLY CRYING FACE}) missing from current font.
#   func(*args, **kwargs)
# E:\DataScience projects\Virtual_demo\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128293 (\N{FIRE}) missing from current font.
#   func(*args, **kwargs)
# E:\DataScience projects\Virtual_demo\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128557 (\N{LOUDLY CRYING FACE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# E:\DataScience projects\Virtual_demo\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128293 (\N{FIRE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
video_data
# Out:
#                                                   Title Published_at   views  \
# 0                    How ChatGPT Can Be Wrong About Me?   2023-02-27    3394
# 1     When Your Kid Doesnt Want You To Work-Just For...   2023-02-24   14817
# 2     Changes Is Inevitable And You Need To Change W...   2023-02-24    8217
# 3     Watch This Video To Crack Any Stats Interview ...   2023-02-23    9044
# 4     What Is Derivatives In  Calculus In Layman Terms?   2023-02-21    2408
# ...                                                 ...          ...     ...
# 1567  Important libraries used in python Data Scienc...   2017-11-26   19442
# 1568  Anaconda installation with Packages- Machine L...   2017-11-26   74012
# 1569  What is Supervised Machine Learning- Machine L...   2017-11-26   33159
# 1570  What is Machine Learning in Data Science- Mach...   2017-11-25  130467
# 1571                  Maeri unplugged by Krish and band   2014-06-01    5067
#
#       Likes  Comment
# 0       126     26.0
# 1       559     61.0
# 2       432     38.0
# 3       490     18.0
# 4       113      9.0
# ...     ...      ...
# 1567    171     15.0
# 1568    337     37.0
# 1569    385     16.0
# 1570    811     46.0
# 1571    130      8.0
#
# [1572 rows x 5 columns]

# %%
video_data['Month']=pd.to_datetime(video_data['Published_at']).dt.strftime('%b')

# %%
video_data
# Out:
#                                                   Title Published_at   views  \
# 0                    How ChatGPT Can Be Wrong About Me?   2023-02-27    3394
# 1     When Your Kid Doesnt Want You To Work-Just For...   2023-02-24   14817
# 2     Changes Is Inevitable And You Need To Change W...   2023-02-24    8217
# 3     Watch This Video To Crack Any Stats Interview ...   2023-02-23    9044
# 4     What Is Derivatives In  Calculus In Layman Terms?   2023-02-21    2408
# ...                                                 ...          ...     ...
# 1567  Important libraries used in python Data Scienc...   2017-11-26   19442
# 1568  Anaconda installation with Packages- Machine L...   2017-11-26   74012
# 1569  What is Supervised Machine Learning- Machine L...   2017-11-26   33159
# 1570  What is Machine Learning in Data Science- Mach...   2017-11-25  130467
# 1571                  Maeri unplugged by Krish and band   2014-06-01    5067
#
#       Likes  Comment Month
# 0       126     26.0   Feb
# 1       559     61.0   Feb
# 2       432     38.0   Feb
# 3       490     18.0   Feb
# 4       113      9.0   Feb
# ...     ...      ...   ...
# 1567    171     15.0   Nov
# 1568    337     37.0   Nov
# 1569    385     16.0   Nov
# 1570    811     46.0   Nov
# 1571    130      8.0   Jun
#
# [1572 rows x 6 columns]

# %%
video_per_month=video_data.groupby('Month',as_index=False).size()
video_per_month
# Out:
#    Month  size
# 0    Apr   129
# 1    Aug   150
# 2    Dec    91
# 3    Feb   139
# 4    Jan   182
# 5    Jul   130
# 6    Jun   151
# 7    Mar   124
# 8    May   131
# 9    Nov   100
# 10   Oct   114
# 11   Sep   131

# %%
sort_order=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

# %%
video_per_month.index=pd.CategoricalIndex(video_per_month['Month'],categories=sort_order,ordered=True)

# %%
video_per_months=video_per_month.sort_index()

# %%
video_per_months
# Out:
#       Month  size
# Month
# Jan     Jan   182
# Feb     Feb   139
# Mar     Mar   124
# Apr     Apr   129
# May     May   131
# Jun     Jun   151
# Jul     Jul   130
# Aug     Aug   150
# Sep     Sep   131
# Oct     Oct   114
# Nov     Nov   100
# Dec     Dec    91

# %%
gt2=sns.barplot(x='Month',y='size',data=video_per_months)
